# %%
import numpy as np

# %% [markdown]
# ## (a)

# %%
arr = np.random.randint(1, 51, size=(4,5))
arr
# Out:
# array([[14, 30, 27, 50, 10],
#        [42, 47, 23,  8,  2],
#        [32, 47, 28, 20,  9],
#        [10, 31, 21,  1, 24]])

# %% [markdown]
# ## (b)

# %%
np.sum(arr)
# Out:
# 476

# %% [markdown]
# ## (c)

# %%
np.max(arr)
# Out:
# 50

# %% [markdown]
# ## (d)

# %%
np.mean(arr)
# Out:
# 23.8

# %% [markdown]
# ## (e)

# %%
np.sum(arr, axis=1)
# Out:
# array([131, 122, 136,  87])

# %% [markdown]
# ## (f)

# %%
arr.T
# Out:
# array([[14, 42, 32, 10],
#        [30, 47, 47, 31],
#        [27, 23, 28, 21],
#        [50,  8, 20,  1],
#        [10,  2,  9, 24]])

# %% [markdown]
# ## (g)

# %%
arr > 25
# Out:
# array([[False,  True,  True,  True, False],
#        [ True,  True, False, False, False],
#        [ True,  True,  True, False, False],
#        [False,  True, False, False, False]])
